# %%
import numpy as np
import pandas as pd
import scanpy as sc
import gc
import sys
import os
sys.path.append('../')
from AIID_notebooks.inflapy.immunoFunc import *

# %% [markdown]
# ##### GSE157278_Hong_2020

# %%
print(sc.__version__)
# Out:
# 1.9.1

# %%
path="/lustre/scratch117/cellgen/cellgeni/TIC-starsolo/tic-1808/GSE157278/"

# %%
s_path = "/nfs/team205/bh14/Datasets/Remapped/raw_adata/"

# %%
#GSE121380/GSM3433578/output/Velocyto/filtered/

pheno = pd.read_csv(s_path+"GSE157278/pheno.csv")

# %%
pheno
# Out:
#            donor_id geo_accession cell_source     sex tissue  \
# 0   HC-1_GSM4760620    GSM4760620        PBMC  female  Blood
# 1   HC-2_GSM4760621    GSM4760621        PBMC  female  Blood
# 2   HC-3_GSM4760622    GSM4760622        PBMC  female  Blood
# 3   HC-4_GSM4760623    GSM4760623        PBMC  female  Blood
# 4   HC-5_GSM4760624    GSM4760624        PBMC  female  Blood
# 5  pSS-1_GSM4760625    GSM4760625        PBMC  female  Blood
# 6  pSS-2_GSM4760626    GSM4760626        PBMC  female  Blood
# 7  pSS-3_GSM4760627    GSM4760627        PBMC  female  Blood
# 8  pSS-4_GSM4760628    GSM4760628        PBMC  female  Blood
# 9  pSS-5_GSM4760629    GSM4760629        PBMC  female  Blood
#
#               disease           dataset_id
# 0             Healthy  GSE157278_Hong_2020
# 1             Healthy  GSE157278_Hong_2020
# 2             Healthy  GSE157278_Hong_2020
# 3             Healthy  GSE157278_Hong_2020
# 4             Healthy  GSE157278_Hong_2020
# 5  Sjögren’s syndrome  GSE157278_Hong_2020
# 6  Sjögren’s syndrome  GSE157278_Hong_2020
# 7  Sjögren’s syndrome  GSE157278_Hong_2020
# 8  Sjögren’s syndrome  GSE157278_Hong_2020
# 9  Sjögren’s syndrome  GSE157278_Hong_2020

# %% [markdown]
# ##### Immune compartment

# %%
for i in range(pheno.shape[0]):
    samp = pheno.geo_accession[i]
    print("Processing "+samp)
    adata = sc.read_10x_mtx(path+samp+"/output/Gene/filtered/")

    #adata.var[['ensembl', 'gene_symbol']]
    
    adata.obs["dataset_id"] = pheno.dataset_id[i]
    adata.obs["donor_id"] = pheno.donor_id[i]
    adata.obs["tissue"] = pheno.tissue[i]
    adata.obs["cell_source"] = pheno.cell_source[i]
    adata.obs["disease"] = pheno.disease[i]
    adata.obs["sex"] = pheno.sex[i]
    
    if 'adata_conc' in locals():
        adata.var_names_make_unique()
        adata_conc.var_names_make_unique()
        adata_conc = sc.concat([adata,adata_conc], index_unique="-")
        
    else:
        adata_conc = adata

    print(adata_conc.shape)
# Out:
# Processing GSM4760620
# (5006, 36601)
# Processing GSM4760621
# (11434, 36601)
# Processing GSM4760622
# (17934, 36601)
# Processing GSM4760623
# (25214, 36601)
# Processing GSM4760624
# (28762, 36601)
# Processing GSM4760625
# (38064, 36601)
# Processing GSM4760626
# (42998, 36601)
# Processing GSM4760627
# (47716, 36601)
# Processing GSM4760628
# (52426, 36601)
# Processing GSM4760629
# (60205, 36601)

# %%
adata_conc
# Out:
# AnnData object with n_obs × n_vars = 60205 × 36601
#     obs: 'dataset_id', 'donor_id', 'tissue', 'cell_source', 'disease', 'sex'

# %%
adata_conc.write_h5ad(s_path+"Immune_compartment/GSE157278_Hong_2020_PBMC.h5ad")
