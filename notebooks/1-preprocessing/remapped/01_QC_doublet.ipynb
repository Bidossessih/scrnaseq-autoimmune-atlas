# %% [markdown]
# **QC and doublet detection**

# %%
import os
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as an
import sys
sys.path.append('../')
from AIID_notebooks.inflapy.immunoFunc import *

# %%
path = '/nfs/team205/bh14/Datasets/Remapped/raw_adata/'

# %%
directory = ["Immune_compartment", "Immune_compartment_sorted_from_Tissue", "Tissue_or_Nonimmune"]

# %%
files = os.listdir(path+directory[0])

# %%
files
# Out:
# ['E-MTAB-9492_Penkava_2020_Immune.h5ad',
#  'GSE134809_Martin_et_al_2019_PBMC.h5ad',
#  'GSE163314_Lefferts_2021_PBMC.h5ad',
#  'GSE157278_Hong_2020_PBMC.h5ad',
#  'Braga_asthma_blood_CD4.h5ad']

# %%
for i in range(len(files)):
        print(str(i)+' '+files[i]+': Processing...')

        adata = sc.read_h5ad(path+dirct+"/"+files[i])
        adataQc(adata=adata, path=path+"QC_Doublet/"+dirct+"/", file=files[i])
# Out:
# 0 E-MTAB-9492_Penkava_2020_Immune.h5ad: Processing...
# #####################################################
# ###                      E-MTAB-9492_Penkava_2020_Immune.h5ad                 ###
# ######################################################
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.83
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 2.6%
# Overall doublet rate:
# 	Expected   = 7.6%
# 	Estimated  = 0.2%
# Elapsed time: 85.3 seconds
# Pass            33020
# High_MT           444
# Low_nFeature      232
# Doublet             2
# Name: QC, dtype: int64
# Plot of metadata only for cells that pass tentative QC:
# 1 GSE134809_Martin_et_al_2019_PBMC.h5ad: Processing...
# #####################################################
# ###                      GSE134809_Martin_et_al_2019_PBMC.h5ad                 ###
# ...

# %% [markdown]
# #### Immune_compartment_sorted_from_Tissue

# %%
directory
# Out:
# ['Immune_compartment',
#  'Immune_compartment_sorted_from_Tissue',
#  'Tissue_or_Nonimmune']

# %%
dirct = directory[1]
files = os.listdir(path+dirct)
files
# Out:
# ['E-MTAB-8322_Stefeno_2020_raw.h5ad',
#  'GSE121380_Huang_2019_immune.h5ad',
#  'Braga_asthma_lung_CD4.h5ad',
#  'E-MTAB-8322_Stefeno_2020.h5ad',
#  'GSE161500_Abji_2020_Synovial_fluid.h5ad',
#  'E-MTAB-9492_Penkava_2020_Immune_from_Synovium.h5ad']

# %%
    
for i in range(len(files)):
    print(str(i)+' '+files[i]+': Processing...')

    adata = sc.read_h5ad(path+dirct+"/"+files[i])
    adataQc(adata=adata, path=path+"QC_Doublet/"+dirct+"/", file=files[i])
# Out:
# 0 E-MTAB-8322_Stefeno_2020_raw.h5ad: Processing...
# #####################################################
# ###                      E-MTAB-8322_Stefeno_2020_raw.h5ad                 ###
# ######################################################
# Preprocessing...
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/scrublet/helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Simulating doublets...

# %% [markdown]
# #### Tissue

# %%
dirct = directory[2]
files = os.listdir(path+dirct)
files
# Out:
# ['GSE134809_Martin_et_al_2019_Ileum.h5ad',
#  'GSE121380_Huang_2019_Non_immune.h5ad',
#  'SDY1599_Wei_2020.h5ad',
#  'Elmentaite_2020_Ileum_Paediatric.h5ad',
#  'E-MTAB-8142_Reynolds_2021.h5ad',
#  'GSE163314_Lefferts_2021_Colon.h5ad',
#  'SDY1765_Cross_tissue_Fibroblast.h5ad',
#  'GSE176308_Nanus_2021_Fibroblast.h5ad']

# %%
    
for i in range(len(files)):
    print(str(i)+' '+files[i]+': Processing...')

    adata = sc.read_h5ad(path+dirct+"/"+files[i])
    adataQc(adata=adata, path=path+"QC_Doublet/"+dirct+"/", file=files[i])
# Out:
# 0 GSE134809_Martin_et_al_2019_Ileum.h5ad: Processing...
# #####################################################
# ###                      GSE134809_Martin_et_al_2019_Ileum.h5ad                 ###
# ######################################################
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 17.7%
# Overall doublet rate:
# 	Expected   = 7.6%
# 	Estimated  = 2.9%
# Elapsed time: 378.6 seconds
# Pass            56829
# Low_nFeature    35924
# High_MT          8941
# Doublet           521
# Name: QC, dtype: int64
# Plot of metadata only for cells that pass tentative QC:
# 1 GSE121380_Huang_2019_Non_immune.h5ad: Processing...
# #####################################################
# ###                      GSE121380_Huang_2019_Non_immune.h5ad                 ###
# ...
