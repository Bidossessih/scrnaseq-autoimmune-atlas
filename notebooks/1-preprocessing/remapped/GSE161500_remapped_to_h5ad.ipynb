# %%
import numpy as np
import pandas as pd
import scanpy as sc
import gc
import sys
import os
sys.path.append('../')
from AIID_notebooks.inflapy.immunoFunc import *

# %% [markdown]
# ##### GSE161500_Abji_2020

# %%
print(sc.__version__)
# Out:
# 1.9.1

# %%
path="/lustre/scratch117/cellgen/cellgeni/TIC-starsolo/tic-1808/GSE161500/"

# %%
s_path = "/nfs/team205/bh14/Datasets/Remapped/raw_adata/"

# %%
#GSE121380/GSM3433578/output/Velocyto/filtered/

pheno = pd.read_csv(s_path+"GSE161500/pheno.csv")

# %%
pheno
# Out:
#                donor_id geo_accession     cell_source          tissue  \
# 0  PsA-22228_GSM4908802    GSM4908802  Synovial fluid  Synovial fluid
# 1   PsA-3830_GSM4908803    GSM4908803  Synovial fluid  Synovial fluid
# 2   PsA-3849_GSM4908804    GSM4908804  Synovial fluid  Synovial fluid
#
#                disease           dataset_id
# 0  Psoriatic arthritis  GSE161500_Abji_2020
# 1  Psoriatic arthritis  GSE161500_Abji_2020
# 2  Psoriatic arthritis  GSE161500_Abji_2020

# %% [markdown]
# ##### Immune compartment

# %%
for i in range(pheno.shape[0]):
    samp = pheno.geo_accession[i]
    print("Processing "+samp)
    adata = sc.read_10x_mtx(path+samp+"/output/Gene/filtered/")

    #adata.var[['ensembl', 'gene_symbol']]
    
    adata.obs["dataset_id"] = pheno.dataset_id[i]
    adata.obs["donor_id"] = pheno.donor_id[i]
    adata.obs["tissue"] = pheno.tissue[i]
    adata.obs["cell_source"] = pheno.cell_source[i]
    adata.obs["disease"] = pheno.disease[i]
    
    if 'adata_conc' in locals():
        adata.var_names_make_unique()
        adata_conc.var_names_make_unique()
        adata_conc = sc.concat([adata,adata_conc], index_unique="-")
        
    else:
        adata_conc = adata

    print(adata_conc.shape)
# Out:
# Processing GSM4908802
# (1304, 36601)
# Processing GSM4908803
# (2367, 36601)
# Processing GSM4908804
# (2718, 36601)

# %%
adata_conc
# Out:
# AnnData object with n_obs × n_vars = 2718 × 36601
#     obs: 'dataset_id', 'donor_id', 'tissue', 'cell_source', 'disease'

# %%
adata_conc.write_h5ad(s_path+"Immune_compartment_sorted_from_Tissue/GSE161500_Abji_2020_Synovial_fluid.h5ad")
