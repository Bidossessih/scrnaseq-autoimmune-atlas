# %%
import os
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as an
import sys
sys.path.append('/home/jovyan/notebooks_bidossessi/Inflammatory/Remapped/autoimmuneSC/AIID_notebooks/')
from inflapy.immunoFunc import *

# %%
s_path = "/nfs/team205/bh14/Datasets/Remapped/raw_adata/ummapped/"

# %% [markdown]
# #### Perez dataset

# %%
perez = sc.read_h5ad(s_path+"PBMC/QC_Doublet/Perez_2022_flare_treated_Healthy.h5ad")

# %%
perez.var.feature_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-d36ea0cbb4b5> in <module>
# ----> 1 perez.var.feature_name
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'feature_name'

# %%
perez.var_names = perez.var.feature_name
# Out:
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/anndata/_core/anndata.py:895: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     ['MIR1302-2HG', 'FAM138A', 'OR4F5', 'RP11-34P13.7', 'RP11-34P13.8']
#
#     Inferred to be: categorical
#
#   names = self._prep_dim_index(names, "var")

# %%
perez.var_names
# Out:
# CategoricalIndex(['MIR1302-2HG', 'FAM138A', 'OR4F5', 'RP11-34P13.7',
#                   'RP11-34P13.8', 'RP11-34P13.14', 'RP11-34P13.9',
#                   'AP006222.1', 'RP4-669L17.4', 'RP4-669L17.2',
#                   ...
#                   'MT-CO2', 'MT-ATP8', 'MT-ATP6', 'MT-CO3', 'MT-ND3',
#                   'MT-ND4L', 'MT-ND4', 'MT-ND5', 'MT-ND6', 'MT-CYB'],
#                  categories=['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', 'A2M-AS1', 'A2ML1', 'A2ML1-AS1', 'A2ML1-AS2', ...], ordered=False, dtype='category', name='feature_name', length=30933)

# %%
perez = perez.raw.to_adata()

# %%
print(perez.X)
# Out:
#   (0, 50)	1.0
#   (0, 55)	1.0
#   (0, 149)	7.0
#   (0, 184)	1.0
#   (0, 382)	1.0
#   (0, 412)	1.0
#   (0, 455)	12.0
#   (0, 480)	2.0
#   (0, 487)	1.0
#   (0, 506)	1.0
#   (0, 520)	5.0
#   (0, 526)	1.0
#   (0, 568)	1.0
#   (0, 569)	1.0
#   (0, 574)	1.0
#   (0, 601)	3.0
#   (0, 627)	1.0
#   (0, 639)	1.0
#   (0, 640)	2.0
#   (0, 714)	1.0
#   (0, 749)	2.0
#   (0, 759)	1.0
#   (0, 807)	1.0
#   (0, 856)	19.0
#   (0, 912)	1.0
#   :	:
#   (567049, 30364)	1.0
#   (567049, 30394)	1.0
#   (567049, 30441)	1.0
#   (567049, 30450)	1.0
#   (567049, 30470)	4.0
#   (567049, 30471)	1.0
#   (567049, 30496)	1.0
#   (567049, 30598)	1.0
#   (567049, 30685)	1.0
#   (567049, 30690)	1.0
#   (567049, 30810)	1.0
#   (567049, 30822)	1.0
#   (567049, 30829)	1.0
#   (567049, 30844)	1.0
#   (567049, 30875)	1.0
#   (567049, 30920)	5.0
#   (567049, 30921)	4.0
#   (567049, 30922)	16.0
#   (567049, 30923)	14.0
#   (567049, 30925)	5.0
#   (567049, 30926)	8.0
#   (567049, 30927)	6.0
#   (567049, 30929)	9.0
#   (567049, 30930)	1.0
#   (567049, 30932)	3.0

# %%
perez.write_h5ad(s_path+"PBMC/QC_Doublet/Perez_2022_flare_treated_Healthy.h5ad")

# %%
del perez
gc.collect()
# Out:
# 677

# %% [markdown]
# #### Qian_Yue_Zhang_2022 dataset

# %%
qian = sc.read_h5ad(s_path+"PBMC/QC_Doublet/Qian_Yue_Zhang_2022.h5ad")
# Out:
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
qian.var_names
# Out:
# Index(['RP11-34P13.3', 'FAM138A', 'OR4F5', 'RP11-34P13.7', 'RP11-34P13.8',
#        'RP11-34P13.14', 'RP11-34P13.9', 'FO538757.3', 'FO538757.2',
#        'AP006222.2',
#        ...
#        'AC007325.2', 'BX072566.1', 'AL354822.1', 'AC023491.2', 'AC004556.1',
#        'AC233755.2', 'AC233755.1', 'AC240274.1', 'AC213203.1', 'FAM231B'],
#       dtype='object', length=33694)

# %%
qian
# Out:
# AnnData object with n_obs × n_vars = 56199 × 33694
#     obs: 'tissue', 'disease', 'donor_id', 'dataset_id', 'cell_source', 'doublet_scores', 'predicted_doublets', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rb', 'pct_counts_rb', 'QC'
#     var: 'mt', 'rb', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %% [markdown]
# #### Martin_JIA dataset

# %%
jia = sc.read_h5ad(s_path+"PBMC/QC_Doublet/Martin_JIA_PBMC.h5ad")

# %%
jia.var_names
# Out:
# Index(['RP11-34P13.3', 'FAM138A', 'OR4F5', 'RP11-34P13.7', 'RP11-34P13.8',
#        'RP11-34P13.14', 'RP11-34P13.9', 'FO538757.3', 'FO538757.2',
#        'AP006222.2',
#        ...
#        'AC007325.2', 'BX072566.1', 'AL354822.1', 'AC023491.2', 'AC004556.1',
#        'AC233755.2', 'AC233755.1', 'AC240274.1', 'AC213203.1', 'FAM231B'],
#       dtype='object', length=33694)

# %%
jia
# Out:
# AnnData object with n_obs × n_vars = 25143 × 33694
#     obs: 'donor_id', 'disease', 'tissue', 'dataset_id', 'sex', 'cell_source', 'development_stage', 'doublet_scores', 'predicted_doublets', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rb', 'pct_counts_rb', 'QC'
#     var: 'mt', 'rb', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %% [markdown]
# #### Lui dataset

# %%
adata_l = sc.read_h5ad(s_path+"PBMC/QC_Doublet/Liu_et_al_2022_PBMC.h5ad")

# %%
adata_l
# Out:
# AnnData object with n_obs × n_vars = 70069 × 33917
#     obs: 'donor_id', 'disease', 'dataset_id', 'tissue', 'cell_source', 'development_stage', 'doublet_scores', 'predicted_doublets', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rb', 'pct_counts_rb', 'QC'
#     var: 'mt', 'rb', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
#### Concat

# %%
adatas = ["Perez_2022_flare_treated_Healthy.h5ad", "Qian_Yue_Zhang_2022.h5ad",
          "Martin_JIA_PBMC.h5ad", "Liu_et_al_2022_PBMC.h5ad"]

# %%
os.listdir(s_path+"PBMC/QC_Doublet/")
# Out:
# ['Qian_Yue_Zhang_2022.h5ad',
#  'Liu_et_al_2022_PBMC.h5ad',
#  'Martin_JIA_PBMC.h5ad',
#  'Perez_2022_flare_treated_Healthy.h5ad']

# %%
path = s_path+"PBMC/QC_Doublet/"
concat_info=[]

for i in range(len(adatas)):
      
    print(str(i)+': reading and concatenating '+adatas[i]+' ...')
        
    adata = sc.read_h5ad(path+adatas[i])
    print(adata.shape)
    
    if 'adata_concat' in locals():
        
        adata_concat.obs_names_make_unique()
        #adata_concat.var_names_make_unique()
        #adata_concat = ad.concat([adata_concat, adata], join="inner", index_unique="_")
        adata_concat = adata_concat.concatenate(adata, join="inner", index_unique="_")
        
    else:
        adata_concat = adata
    
    print(adata_concat.shape)
    mydict = {'Dataset':adatas[i],'Tissue':adata.obs['tissue'].unique().to_list(),
              'Cell_num':adata.shape[0], 'Gene_num':adata.shape[1], 'gene_after_concat':adata_concat.shape[1]
             }
    a_mydict = mydict.copy()
    #print(a_mydict)
    #I used .copy() and ignore_index=True to avoid error when appending dict to list
    concat_info.append(a_mydict.copy())
    #concat_info = pd.json_normalize(concat_info)
    # Show QC of each dataset
    #showAdataQc(adata=adata,file=files[i])
    del adata
    gc.collect()
    #adata_concat = sc.concat(adatas, join="inner", index_unique="_", uns_merge='unique')
# Out:
# 0: reading and concatenating Perez_2022_flare_treated_Healthy.h5ad ...
# (567050, 30933)
# (567050, 30933)
# 1: reading and concatenating Qian_Yue_Zhang_2022.h5ad ...
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# (56199, 33694)
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/anndata/_core/anndata.py:798: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     []
#
#     Inferred to be: empty
#
#   value_idx = self._prep_dim_index(value.index, attr)
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/anndata/_core/anndata.py:798: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     []
#
#     Inferred to be: empty
#
#   value_idx = self._prep_dim_index(value.index, attr)
# (623249, 0)
# 2: reading and concatenating Martin_JIA_PBMC.h5ad ...
# (25143, 33694)
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/anndata/_core/anndata.py:798: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     []
#
#     Inferred to be: empty
#
#   value_idx = self._prep_dim_index(value.index, attr)
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/anndata/_core/anndata.py:798: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     []
#
#     Inferred to be: empty
#
#   value_idx = self._prep_dim_index(value.index, attr)
# (648392, 0)
# 3: reading and concatenating Liu_et_al_2022_PBMC.h5ad ...
# (70069, 33917)
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# (718461, 0)
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/anndata/_core/anndata.py:798: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     []
#
#     Inferred to be: empty
#
#   value_idx = self._prep_dim_index(value.index, attr)
# /home/jovyan/my-conda-envs/autoimmune/lib/python3.8/site-packages/anndata/_core/anndata.py:798: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     []
#
#     Inferred to be: empty
#
#   value_idx = self._prep_dim_index(value.index, attr)

# %%
concat_info
# Out:
# [{'Dataset': 'Perez_2022_flare_treated_Healthy.h5ad',
#   'Tissue': ['Blood'],
#   'Cell_num': 567050,
#   'Gene_num': 30933,
#   'gene_after_concat': 30933},
#  {'Dataset': 'Qian_Yue_Zhang_2022.h5ad',
#   'Tissue': ['Thyroid'],
#   'Cell_num': 56199,
#   'Gene_num': 33694,
#   'gene_after_concat': 0},
#  {'Dataset': 'Martin_JIA_PBMC.h5ad',
#   'Tissue': ['Blood'],
#   'Cell_num': 25143,
#   'Gene_num': 33694,
#   'gene_after_concat': 0},
#  {'Dataset': 'Liu_et_al_2022_PBMC.h5ad',
#   'Tissue': ['Blood'],
#   'Cell_num': 70069,
#   'Gene_num': 33917,
#   'gene_after_concat': 0}]

# %%
adata_concat
# Out:
# AnnData object with n_obs × n_vars = 718461 × 0
#     obs: 'disease', 'sex', 'tissue', 'development_stage', 'author_annotation', 'disease_state', 'donor_id', 'dataset_id', 'cell_source', 'age', 'doublet_scores', 'predicted_doublets', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rb', 'pct_counts_rb', 'QC', 'batch'
#     var: 'feature_biotype-0-0-0', 'mt-1-0-0', 'rb-1-0-0', 'n_cells_by_counts-1-0-0', 'mean_counts-1-0-0', 'pct_dropout_by_counts-1-0-0', 'total_counts-1-0-0', 'mt-1-0', 'rb-1-0', 'n_cells_by_counts-1-0', 'mean_counts-1-0', 'pct_dropout_by_counts-1-0', 'total_counts-1-0', 'mt-1', 'rb-1', 'n_cells_by_counts-1', 'mean_counts-1', 'pct_dropout_by_counts-1', 'total_counts-1'

# %%
def filter_norma(adata, min_genes=500, min_donor=50):
    #sc.pp.filter_cells(adata, min_counts=min_counts)

    sc.pp.filter_cells(adata, min_genes=min_genes)

    adata = adata[adata.obs['QC'] == 'Pass']

    # Remove donors with few than 50 cells
    donor_counts = adata.obs['donor_id'].value_counts()

    donor_counts.sort_values()[:30]

    donor_counts[donor_counts<min_donor].sum()

    adata = adata[adata.obs['donor_id'].isin( donor_counts[donor_counts>=min_donor].index)]
    
    adata.layers["counts"] = adata.X.copy()
# size and log1p normalization
    sc.pp.normalize_total(adata, target_sum=1e4)
    sc.pp.log1p(adata)

    adata.raw = adata  # keep full dimension safe
    return adata

# %%
adata_concat = filter_norma(adata=adata_concat)
# Out:
# <ipython-input-15-946fca008fe8>:17: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   adata.layers["counts"] = adata.X.copy()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-950df19e37d8> in <module>
# ----> 1 adata_concat = filter_norma(adata=adata_concat)
#
# <ipython-input-15-946fca008fe8> in filter_norma(adata, min_genes, min_donor)
#      18 # size and log1p normalization
#      19     sc.pp.normalize_total(adata, target_sum=1e4)
# ---> 20     sc.pp.log1p(adata)
#      21
#      22     adata.raw = adata  # keep full dimension safe
#
# ~/my-conda-envs/autoimmune/lib/python3.8/functools.py in wrapper(*args, **kw)
#     873                             '1 positional argument')
#     874
# --> 875         return dispatch(args[0].__class__)(*args, **kw)
#     876
#     877     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/.local/lib/python3.8/site-packages/scanpy/preprocessing/_simple.py in log1p_anndata(adata, base, copy, chunked, chunk_size, layer, obsm)
#     382     else:
#     383         X = _get_obs_rep(adata, layer=layer, obsm=obsm)
# --> 384         X = log1p(X, copy=False, base=base)
#     385         _set_obs_rep(adata, X, layer=layer, obsm=obsm)
#     386
#
# ~/my-conda-envs/autoimmune/lib/python3.8/functools.py in wrapper(*args, **kw)
#     873                             '1 positional argument')
#     874
# --> 875         return dispatch(args[0].__class__)(*args, **kw)
#     876
#     877     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/.local/lib/python3.8/site-packages/scanpy/preprocessing/_simple.py in log1p_sparse(X, base, copy)
#     332 @log1p.register(spmatrix)
#     333 def log1p_sparse(X, *, base: Optional[Number] = None, copy: bool = False):
# --> 334     X = check_array(
#     335         X, accept_sparse=("csr", "csc"), dtype=(np.float64, np.float32), copy=copy
#     336     )
#
# ~/my-conda-envs/autoimmune/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/my-conda-envs/autoimmune/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     667         n_samples = _num_samples(array)
#     668         if n_samples < ensure_min_samples:
# --> 669             raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#     670                              " minimum of %d is required%s."
#     671                              % (n_samples, array.shape, ensure_min_samples,
#
# ValueError: Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.

# %%
adata_concat.obs.dataset_id.value_counts()

# %%
pd.DataFrame(concat_info)
