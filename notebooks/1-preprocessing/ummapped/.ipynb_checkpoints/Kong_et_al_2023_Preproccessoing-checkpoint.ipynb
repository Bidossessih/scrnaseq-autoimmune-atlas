# %%
import os
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as an
import sys
sys.path.append('/home/jovyan/notebooks_bidossessi/Inflammatory/Remapped/autoimmuneSC/AIID_notebooks/')

from inflapy.immunoFunc import *

# %%
path = "/nfs/team205/bh14/Datasets/RawData/raw_and_AnnData/annDataModified/Kong_et_al_2023_modified.h5ad"

s_path = "/nfs/team205/bh14/Datasets/Remapped/raw_adata/ummapped/"

# %%
#os.listdir(path)

# %% [markdown]
# #### Kong dataset

# %%
adata = sc.read_h5ad(path)

# %%
adata.var_names
# Out:
# Index(['AL627309.1', 'AP006222.2', 'RP4-669L17.10', 'RP11-206L10.3',
#        'RP11-206L10.2', 'RP11-206L10.9', 'FAM87B', 'LINC00115', 'FAM41C',
#        'RP11-54O7.3',
#        ...
#        'RP11-236J17.6', 'AP000479.1', 'GLYAT', 'LACRT', 'LINC00555',
#        'LINC00676', 'RP11-739N10.1', 'CTB-60B18.18', 'CTD-2616J11.3',
#        'AC006272.2'],
#       dtype='object', length=27830)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 353581 × 27830
#     obs: 'Site', 'donor_id', 'disease', 'dataset_id', 'tissue'

# %%
adata.obs.tissue.value_counts()
# Out:
# ileum    201072
# colon    152509
# Name: tissue, dtype: int64

# %%
adata.obs
# Out:
#                             Site    donor_id      disease       dataset_id  \
# N105446_L-TGTCCTGGTCCCGTGA    CO   N105446_L  Uninflam_CD  Kong_et_al_2023
# N105446_L-CCTACGTGTGAATGTA    CO   N105446_L  Uninflam_CD  Kong_et_al_2023
# N105446_L-TATCCTAGTGACAGGT    CO   N105446_L  Uninflam_CD  Kong_et_al_2023
# N105446_L-CTGCATCAGCACCTGC    CO   N105446_L  Uninflam_CD  Kong_et_al_2023
# N105446_L-GGTGATTAGAACCCGA    CO   N105446_L  Uninflam_CD  Kong_et_al_2023
# ...                          ...         ...          ...              ...
# N119540_L2-CACTGGGAGCTGACCC   TI  N119540_L2  Uninflam_CD  Kong_et_al_2023
# N119540_L2-CGAGGCTTCTCACTCG   TI  N119540_L2  Uninflam_CD  Kong_et_al_2023
# N119540_L2-CTCAAGATCTACGCGG   TI  N119540_L2  Uninflam_CD  Kong_et_al_2023
# N119540_L2-TATTCCATCGCCTAGG   TI  N119540_L2  Uninflam_CD  Kong_et_al_2023
# N119540_L2-CATCGTCGTCACTTCC   TI  N119540_L2  Uninflam_CD  Kong_et_al_2023
#
#                             tissue
# N105446_L-TGTCCTGGTCCCGTGA   colon
# N105446_L-CCTACGTGTGAATGTA   colon
# N105446_L-TATCCTAGTGACAGGT   colon
# N105446_L-CTGCATCAGCACCTGC   colon
# N105446_L-GGTGATTAGAACCCGA   colon
# ...                            ...
# N119540_L2-CACTGGGAGCTGACCC  ileum
# N119540_L2-CGAGGCTTCTCACTCG  ileum
# N119540_L2-CTCAAGATCTACGCGG  ileum
# N119540_L2-TATTCCATCGCCTAGG  ileum
# N119540_L2-CATCGTCGTCACTTCC  ileum
#
# [353581 rows x 5 columns]

# %%
#adata.obs["cell_source"] = adata.obs["tissue"].str.replace("_HC", "").str.replace("_BD", "")

# %%
#adata.obs["tissue"] = np.repeat("Blood", adata.n_obs)

# %%
adata.obs
# Out:
#                             Site    donor_id      disease       dataset_id  \
# N105446_L-TGTCCTGGTCCCGTGA    CO   N105446_L  Uninflam_CD  Kong_et_al_2023
# N105446_L-CCTACGTGTGAATGTA    CO   N105446_L  Uninflam_CD  Kong_et_al_2023
# N105446_L-TATCCTAGTGACAGGT    CO   N105446_L  Uninflam_CD  Kong_et_al_2023
# N105446_L-CTGCATCAGCACCTGC    CO   N105446_L  Uninflam_CD  Kong_et_al_2023
# N105446_L-GGTGATTAGAACCCGA    CO   N105446_L  Uninflam_CD  Kong_et_al_2023
# ...                          ...         ...          ...              ...
# N119540_L2-CACTGGGAGCTGACCC   TI  N119540_L2  Uninflam_CD  Kong_et_al_2023
# N119540_L2-CGAGGCTTCTCACTCG   TI  N119540_L2  Uninflam_CD  Kong_et_al_2023
# N119540_L2-CTCAAGATCTACGCGG   TI  N119540_L2  Uninflam_CD  Kong_et_al_2023
# N119540_L2-TATTCCATCGCCTAGG   TI  N119540_L2  Uninflam_CD  Kong_et_al_2023
# N119540_L2-CATCGTCGTCACTTCC   TI  N119540_L2  Uninflam_CD  Kong_et_al_2023
#
#                             tissue
# N105446_L-TGTCCTGGTCCCGTGA   colon
# N105446_L-CCTACGTGTGAATGTA   colon
# N105446_L-TATCCTAGTGACAGGT   colon
# N105446_L-CTGCATCAGCACCTGC   colon
# N105446_L-GGTGATTAGAACCCGA   colon
# ...                            ...
# N119540_L2-CACTGGGAGCTGACCC  ileum
# N119540_L2-CGAGGCTTCTCACTCG  ileum
# N119540_L2-CTCAAGATCTACGCGG  ileum
# N119540_L2-TATTCCATCGCCTAGG  ileum
# N119540_L2-CATCGTCGTCACTTCC  ileum
#
# [353581 rows x 5 columns]

# %%
gc.collect()
# Out:
# 17

# %%
adata.var_names
# Out:
# Index(['AL627309.1', 'AP006222.2', 'RP4-669L17.10', 'RP11-206L10.3',
#        'RP11-206L10.2', 'RP11-206L10.9', 'FAM87B', 'LINC00115', 'FAM41C',
#        'RP11-54O7.3',
#        ...
#        'RP11-236J17.6', 'AP000479.1', 'GLYAT', 'LACRT', 'LINC00555',
#        'LINC00676', 'RP11-739N10.1', 'CTB-60B18.18', 'CTD-2616J11.3',
#        'AC006272.2'],
#       dtype='object', length=27830)

# %%
adataQc(adata=adata, path=s_path+"Tissue/QC_Doublet/", file="Kong_CD_2023")
# Out:
# #####################################################
# ###                      Kong_CD_2023                 ###
# ######################################################
# Preprocessing...

# %%
adata.obs.donor_id.value_counts()
# Out:
# d6b9e3a7-9f15-4931-a07d-4f4a03991d68    13543
# 1d15a70f-8b4c-4d49-a08b-c7098cd3b170    12768
# 79dd16e4-4d95-445f-a2b8-2d2e10872774    12491
# 4ea8244c-06f7-49b6-b246-63195f85a392    11178
# 03b233c8-d3e2-4438-8b04-0b6621fb5635    10382
#                                         ...
# e3d72ad1-03a0-4358-9dc6-cec4b8018512     1899
# 1bed79e5-39d1-461e-a189-7a70e95b250d     1810
# 2a3821dd-89d1-4f22-b36e-6d2630e71e16     1487
# 88e90be3-39e5-4a3b-9218-6f849e4dc8db     1189
# 94ac9d2f-36bb-4998-8213-dde641efebb1      456
# Name: donor_id, Length: 118, dtype: int64
