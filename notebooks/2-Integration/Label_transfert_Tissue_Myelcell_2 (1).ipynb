# %%
import os
import matplotlib as mpl
import numpy as np
import pandas as pd
import scanpy as sc
import celltypist
from celltypist import models
import scvi
import gc

sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=80, facecolor='white', color_map='viridis')
sc.logging.print_header()
# Out:
# scanpy==1.9.8 anndata==0.10.5.post1 umap==0.5.5 numpy==1.26.4 scipy==1.12.0 pandas==1.5.3 scikit-learn==1.4.1.post1 statsmodels==0.14.1 igraph==0.11.4 pynndescent==0.5.11

# %%
import scarches as sca
#from scarches.dataset.trvae.data_handling import remove_sparsity
# Out:
# In order to use the mouse gastrulation seqFISH datsets, please install squidpy (see https://github.com/scverse/squidpy).
# In order to use sagenet models, please install pytorch geometric (see https://pytorch-geometric.readthedocs.io) and
#  captum (see https://github.com/pytorch/captum).
# mvTCR is not installed. To use mvTCR models, please install it first using "pip install mvtcr"
# multigrate is not installed. To use multigrate models, please install it first using "pip install multigrate".

# %%
import torch

# %%
import gdown
#import scarches as sca
#from scarches.dataset.trvae.data_handling import remove_sparsity

# %%
torch.set_printoptions(precision=3, sci_mode=False, edgeitems=7)

# %%
print(sc.__version__)
# Out:
# 1.9.8

# %%
print(scvi.__version__)
# Out:
# 1.1.1

# %%
#dir_save="/nfs/team205/bh14/Datasets/Remapped/raw_adata/SCVI_Results/Immune_compartment_PBMC/Subset/"
#path='/nfs/team205/bh14/Datasets/Remapped/raw_adata/QC_concatenated/'

# %%
#adata = sc.read_h5ad('Immune_compartment_QC_filtered_2.h5ad')

# %%
#del adata

# %%
def load_sub_adata(adata, obs_file):
    obs = pd.read_csv(obs_file, index_col=0)
    if "scvi_clusters" in obs.columns:
        obs.drop(columns="scvi_clusters", inplace=True)
    temp = adata[obs.index].copy()
    temp.obs = obs
    return temp

# %%
def load_model(adata, save_path, obs_file_path):
    
    adata_hvg = load_sub_adata(adata=adata, obs_file=obs_file_path)
    
    print("running hvg")

    sc.pp.highly_variable_genes(
        adata_hvg, 
        flavor="seurat_v3", 
        n_top_genes=2000, 
        layer="counts", 
        batch_key="batch",
        subset=True
    )
                               
    print("loading model .....")
    
    vae = scvi.model.SCVI.load(save_path, adata=adata_hvg, use_gpu=True)
    vae.get_latent_representation()
    
    return vae

# %%
dir_save="/nfs/team205/bh14/Datasets/Remapped/raw_adata/SCVI_Results/All_Tissue_or_Nonimmune/Subset/"
path='/nfs/team205/bh14/Datasets/Remapped/raw_adata/ummapped/Tissue/QC_Doublet_concat/'

# %%
adata_query = sc.read_h5ad("Braga_asthma_lung_celltypist.h5ad")

# %%
sc.set_figure_params(figsize=(9,9))

# %%
adata_query
# Out:
# AnnData object with n_obs × n_vars = 96803 × 27468
#     obs: 'dataset_id', 'donor_id', 'tissue', 'cell_source', 'disease', 'disease_status', 'age', 'sex', 'developmental_stage', 'sample_id', 'n_counts', 'doublet_scores', 'predicted_doublets', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rb', 'pct_counts_rb', 'QC', 'n_genes', 'predicted_labels', 'over_clustering', 'majority_voting', 'conf_score', 'main_predicted_cell_groups'
#     var: 'n_counts', 'mt', 'rb', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'leiden', 'log1p', 'neighbors'
#     obsm: 'X_pca'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
sc.tl.pca(adata_query, svd_solver='arpack')
# Out:
# computing PCA
#     with n_comps=50
#     finished (0:01:28)

# %%
sc.pl.pca(adata_query, color='CD14')

# %%
sc.pl.pca_variance_ratio(adata_query, log=True)

# %%
sc.pp.neighbors(adata_query, n_neighbors=30, n_pcs=15)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 15
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:19)

# %%
sc.tl.paga(adata_query)
sc.pl.paga(adata_query, plot=False)  # remove `plot=False` if you want to see the coarse-grained graph
sc.tl.umap(adata_query, init_pos='paga')

# %%
sc.set_figure_params(figsize=(12,12))
sc.pl.umap(
    adata_query,
    color=["majority_voting", "main_predicted_cell_groups"],
    frameon=False,
    size=6,
    ncols=2,
    legend_fontoutline=4,
    legend_fontsize=10,
    legend_loc="on data"
)

# %%
#adata_query.write_h5ad('Braga_asthma_lung_celltypist.h5ad')

# %%
adata_query = sc.read_h5ad("Braga_asthma_lung_celltypist.h5ad")

# %%
adata_query.obs.main_predicted_cell_groups.unique()[:10]
# Out:
# ['Multiciliated (non-nasal)', 'Basal resting', 'Suprabasal', 'EC venous systemic', 'Goblet (nasal)', 'Classical monocytes', 'Club (non-nasal)', 'Mast cells', 'CD4 T cells', 'DC2']
# Categories (26, object): ['Alveolar macrophages', 'B cells', 'Basal resting', 'CD4 T cells', ..., 'SMG mucous', 'SMG serous (bronchial)', 'Smooth muscle', 'Suprabasal']

# %%
adata_query.obs.main_predicted_cell_groups.unique()[10:20]
# Out:
# ['SMG mucous', 'CD8 T cells', 'Peribronchial fibroblasts', 'Non-classical monocytes', 'SMG duct', 'SMG serous (bronchial)', 'Alveolar macrophages', 'EC arterial', 'Ionocyte', 'NK cells']
# Categories (26, object): ['Alveolar macrophages', 'B cells', 'Basal resting', 'CD4 T cells', ..., 'SMG mucous', 'SMG serous (bronchial)', 'Smooth muscle', 'Suprabasal']

# %%
adata_query.obs.main_predicted_cell_groups.unique()[20:]
# Out:
# ['Smooth muscle', 'B cells', 'Plasmacytoid DCs', 'Plasma cells', 'Lymphatic EC mature', 'Goblet (bronchial)']
# Categories (26, object): ['Alveolar macrophages', 'B cells', 'Basal resting', 'CD4 T cells', ..., 'SMG mucous', 'SMG serous (bronchial)', 'Smooth muscle', 'Suprabasal']

# %%
adata_query.obs.main_predicted_cell_groups.value_counts()
# Out:
# Multiciliated (non-nasal)    33032
# Suprabasal                   22014
# Basal resting                12363
# CD8 T cells                   7264
# CD4 T cells                   4595
# Club (non-nasal)              4052
# EC venous systemic            3208
# DC2                           1700
# Classical monocytes           1671
# Peribronchial fibroblasts     1182
# B cells                        802
# Mast cells                     793
# Plasma cells                   558
# Goblet (bronchial)             508
# Goblet (nasal)                 465
# Smooth muscle                  415
# NK cells                       371
# SMG duct                       313
# Ionocyte                       279
# SMG serous (bronchial)         270
# Non-classical monocytes        240
# EC arterial                    224
# SMG mucous                     184
# Alveolar macrophages           133
# Plasmacytoid DCs               126
# Lymphatic EC mature             41
# Name: main_predicted_cell_groups, dtype: int64

# %%
adata_query = adata_query[adata_query.obs.main_predicted_cell_groups.isin(['Classical monocytes', 'Mast cells', 'CD4 T cells', 
                                                           'DC2', 'CD8 T cells', 'Non-classical monocytes', 'NK cells', 
                                                           'B cells', 'Alveolar macrophages', 'Plasmacytoid DCs', 'Plasma cells'])].copy()

# %%
adata_query
# Out:
# AnnData object with n_obs × n_vars = 18253 × 27468
#     obs: 'dataset_id', 'donor_id', 'tissue', 'cell_source', 'disease', 'disease_status', 'age', 'sex', 'developmental_stage', 'sample_id', 'n_counts', 'doublet_scores', 'predicted_doublets', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rb', 'pct_counts_rb', 'QC', 'n_genes', 'predicted_labels', 'over_clustering', 'majority_voting', 'conf_score', 'main_predicted_cell_groups', 'leiden'
#     var: 'n_counts', 'mt', 'rb', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'leiden', 'leiden_sizes', 'log1p', 'main_predicted_cell_groups_colors', 'majority_voting_colors', 'neighbors', 'paga', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(
    adata_query,
    color=["main_predicted_cell_groups", "majority_voting"],
    frameon=False,
    size=6,
    ncols=2,
    #legend_loc="on data"
)

# %%
marker_genes = ['CD74', 'HLA-DRA', 'CLEC9A', 'DNASE1L3', 'IDO1', 'XCR1', 'FCER1A', 'S100A9',
               'CLEC10A', 'CD1C', 'PKIB', 'FSCN1',  'LAMP3', 'CCR7', 'CD14', 'FCGR3A', 'C1QA', 
                'CRISPLD2', 'CLU', 'CDKN1C', 'ZNF703', 'CX3CR1', 'GPNMB', 'TREM2', 'BHLHE41', 
                'TNIP3', 'CCL2', 'SLC40A1', 'VCAM1', 'CD209', 'SDS', 'IGF1', 'MKI67', 'TOP2A', 
                #'CD3E', 
                'ITGAM', 'SIRPA']

# %%
sc.pl.dotplot(adata_query, marker_genes + ['IL1B', 'IFNG', 'TNF', 'HLA-DMB', 'LGALS2', 'NCF1', 'S100A12', 'VCAN'],
              groupby='majority_voting', standard_scale='var',
              cmap='OrRd', swap_axes=False)

# %% [markdown]
# #### Analyze reference and query

# %%
adata_ref = sc.read_h5ad("Myeloid_B_T_From_Tissue_label_transfert_Subset_annotated_Milo_3K.h5ad")

# %%
adata_ref
# Out:
# AnnData object with n_obs × n_vars = 48398 × 36601
#     obs: 'dataset_id', 'donor_id', 'tissue', 'cell_source', 'disease', 'doublet_scores', 'predicted_doublets', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rb', 'pct_counts_rb', 'QC', 'barcodes', 'batch', 'disease_status', 'age', 'sex', 'developmental_stage', 'development_stage', 'barcode', 'sample_id', 'Site', 'Enrichment', 'Location', 'full_clustering', 'log1p_total_counts', 'author_annotation', 'n_genes', 'predicted_labels', 'over_clustering', 'majority_voting', 'conf_score', 'leiden_1_5', 'tissue_harmo', 'leiden', 'leiden_man', 'cell_type', 'score', 'leiden_R', 'relabeled_cells'
#     var: 'mt-0', 'rb-0', 'n_cells_by_counts-0-0-0-0-0', 'mean_counts-0-0-0-0-0', 'pct_dropout_by_counts-0-0-0-0-0', 'total_counts-0-0-0-0-0', 'n_cells_by_counts-1-0-0-0-0', 'mean_counts-1-0-0-0-0', 'pct_dropout_by_counts-1-0-0-0-0', 'total_counts-1-0-0-0-0', 'gene_ids-1-0-0-0-0', 'feature_types-1-0-0-0-0', 'n_cells_by_counts-1-0-0-0', 'mean_counts-1-0-0-0', 'pct_dropout_by_counts-1-0-0-0', 'total_counts-1-0-0-0', 'n_cells_by_counts-1-0-0', 'mean_counts-1-0-0', 'pct_dropout_by_counts-1-0-0', 'total_counts-1-0-0', 'n_cells_by_counts-1-0', 'mean_counts-1-0', 'pct_dropout_by_counts-1-0', 'total_counts-1-0', 'n_cells_by_counts-1-0-0-0-1', 'mean_counts-1-0-0-0-1', 'pct_dropout_by_counts-1-0-0-0-1', 'total_counts-1-0-0-0-1', 'n_cells_by_counts-1-0-0-1', 'mean_counts-1-0-0-1', 'pct_dropout_by_counts-1-0-0-1', 'total_counts-1-0-0-1', 'n_cells_by_counts-1-0-1', 'mean_counts-1-0-1', 'pct_dropout_by_counts-1-0-1', 'total_counts-1-0-1', 'n_cells_by_counts-1-1', 'mean_counts-1-1', 'pct_dropout_by_counts-1-1', 'total_counts-1-1', 'mt-0-0-0-0-1', 'rb-0-0-0-0-1', 'n_cells_by_counts-0-0-0-0-0-0-0-1', 'mean_counts-0-0-0-0-0-0-0-1', 'pct_dropout_by_counts-0-0-0-0-0-0-0-1', 'total_counts-0-0-0-0-0-0-0-1', 'n_cells_by_counts-1-0-0-0-0-0-0-1', 'mean_counts-1-0-0-0-0-0-0-1', 'pct_dropout_by_counts-1-0-0-0-0-0-0-1', 'total_counts-1-0-0-0-0-0-0-1', 'ensembl-1-0-0-0-0-0-0-1', 'gene_symbol-1-0-0-0-0-0-0-1', 'n_cells_by_counts-1-0-0-0-0-0-1', 'mean_counts-1-0-0-0-0-0-1', 'pct_dropout_by_counts-1-0-0-0-0-0-1', 'total_counts-1-0-0-0-0-0-1', 'n_cells_by_counts-1-0-0-0-0-1', 'mean_counts-1-0-0-0-0-1', 'pct_dropout_by_counts-1-0-0-0-0-1', 'total_counts-1-0-0-0-0-1', 'mt-1-0-0-0-1', 'rb-1-0-0-0-1', 'gene_name-1-0-0-0-1', 'mt-1-0-0-1', 'rb-1-0-0-1', 'mt-1-0-1', 'rb-1-0-1', 'mt-1-1', 'rb-1-1'
#     uns: 'cell_type_colors', 'dataset_id_colors', 'dendrogram_cell_type', 'leiden', 'leiden_1_5_colors', 'leiden_R_colors', 'leiden_man_colors', 'log1p', 'majority_voting_colors', 'rank_genes_groups', 'relabeled_cells_colors', 'scvi_neighbors', 'umap'
#     obsm: 'X_pca', 'X_scVI', 'X_umap'
#     layers: 'counts'
#     obsp: 'scvi_neighbors_connectivities', 'scvi_neighbors_distances'

# %%
sc.set_figure_params(figsize=(8,8))
sc.pl.umap(
    adata_ref,
    color=['leiden_man', 'cell_type'],
    ncols=2,
    frameon=False,
    size=10,
    legend_fontoutline=3,
    legend_loc='on data'
)

# %%
save_path="scvi_model_Myeloid_From_Tissue_Subset_5/"

# %%
scvi.model.SCVI.prepare_query_anndata(adata=adata_ref, reference_model=dir_save + save_path)
# Out:
# INFO     File /nfs/team205/bh14/Datasets/Remapped/raw_adata/SCVI_Results/All_Tissue_or_Nonimm
#          une/Subset/scvi_model_Myeloid_From_Tissue_Subset_5/model.pt already downloaded
# INFO     Found 100.0% reference vars in query data.

# %%
vae_ref = scvi.model.SCVI.load_query_data(reference_model=dir_save + save_path, adata=adata_ref)
# Out:
# INFO     File /nfs/team205/bh14/Datasets/Remapped/raw_adata/SCVI_Results/All_Tissue_or_Nonimm
#          une/Subset/scvi_model_Myeloid_From_Tissue_Subset_5/model.pt already downloaded
# Unable to initialize backend 'tpu_driver': NOT_FOUND: Unable to find driver in registry given worker:
# Unable to initialize backend 'cuda': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# Unable to initialize backend 'tpu': INVALID_ARGUMENT: TpuPlatform is not available.

# %%
# unlabeled category does not exist in adata.obs[labels_key]
# so all cells are treated as labeled
vae_ref_scan = scvi.model.SCANVI.from_scvi_model(
    vae_ref,
    unlabeled_category="Unknown",
    labels_key="cell_type",
)

# %%
vae_ref_scan.train(max_epochs=100, n_samples_per_label=100)
# Out:
# INFO     Training for 100 epochs.
# Created a temporary directory at /tmp/tmp4xvqkn40
# Writing /tmp/tmp4xvqkn40/_remote_module_non_scriptable.py
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 100/100: 100%|██████████| 100/100 [32:00<00:00, 19.21s/it, loss=621, v_num=1]

# %%
adata_ref.obsm["X_scANVI"] = vae_ref_scan.get_latent_representation()
sc.pp.neighbors(adata_ref, use_rep="X_scANVI")
sc.tl.leiden(adata_ref)
sc.tl.umap(adata_ref)
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:37)
# running Leiden clustering
#     finished: found 18 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:09)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:01:09)

# %%
sc.pl.umap(
    adata_ref,
    color=["cell_type"],
    frameon=False,
    ncols=1,
    size=10

)

# %%
adata_ref
# Out:
# AnnData object with n_obs × n_vars = 48398 × 2000
#     obs: 'dataset_id', 'donor_id', 'tissue', 'cell_source', 'disease', 'doublet_scores', 'predicted_doublets', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rb', 'pct_counts_rb', 'QC', 'barcodes', 'batch', 'disease_status', 'age', 'sex', 'developmental_stage', 'development_stage', 'barcode', 'sample_id', 'Site', 'Enrichment', 'Location', 'full_clustering', 'log1p_total_counts', 'author_annotation', 'n_genes', 'predicted_labels', 'over_clustering', 'majority_voting', 'conf_score', 'leiden_1_5', 'tissue_harmo', 'leiden', 'leiden_man', 'cell_type', 'score', 'leiden_R', 'relabeled_cells', '_scvi_batch', '_scvi_labels'
#     var: 'mt-0', 'rb-0', 'n_cells_by_counts-0-0-0-0-0', 'mean_counts-0-0-0-0-0', 'pct_dropout_by_counts-0-0-0-0-0', 'total_counts-0-0-0-0-0', 'n_cells_by_counts-1-0-0-0-0', 'mean_counts-1-0-0-0-0', 'pct_dropout_by_counts-1-0-0-0-0', 'total_counts-1-0-0-0-0', 'gene_ids-1-0-0-0-0', 'feature_types-1-0-0-0-0', 'n_cells_by_counts-1-0-0-0', 'mean_counts-1-0-0-0', 'pct_dropout_by_counts-1-0-0-0', 'total_counts-1-0-0-0', 'n_cells_by_counts-1-0-0', 'mean_counts-1-0-0', 'pct_dropout_by_counts-1-0-0', 'total_counts-1-0-0', 'n_cells_by_counts-1-0', 'mean_counts-1-0', 'pct_dropout_by_counts-1-0', 'total_counts-1-0', 'n_cells_by_counts-1-0-0-0-1', 'mean_counts-1-0-0-0-1', 'pct_dropout_by_counts-1-0-0-0-1', 'total_counts-1-0-0-0-1', 'n_cells_by_counts-1-0-0-1', 'mean_counts-1-0-0-1', 'pct_dropout_by_counts-1-0-0-1', 'total_counts-1-0-0-1', 'n_cells_by_counts-1-0-1', 'mean_counts-1-0-1', 'pct_dropout_by_counts-1-0-1', 'total_counts-1-0-1', 'n_cells_by_counts-1-1', 'mean_counts-1-1', 'pct_dropout_by_counts-1-1', 'total_counts-1-1', 'mt-0-0-0-0-1', 'rb-0-0-0-0-1', 'n_cells_by_counts-0-0-0-0-0-0-0-1', 'mean_counts-0-0-0-0-0-0-0-1', 'pct_dropout_by_counts-0-0-0-0-0-0-0-1', 'total_counts-0-0-0-0-0-0-0-1', 'n_cells_by_counts-1-0-0-0-0-0-0-1', 'mean_counts-1-0-0-0-0-0-0-1', 'pct_dropout_by_counts-1-0-0-0-0-0-0-1', 'total_counts-1-0-0-0-0-0-0-1', 'ensembl-1-0-0-0-0-0-0-1', 'gene_symbol-1-0-0-0-0-0-0-1', 'n_cells_by_counts-1-0-0-0-0-0-1', 'mean_counts-1-0-0-0-0-0-1', 'pct_dropout_by_counts-1-0-0-0-0-0-1', 'total_counts-1-0-0-0-0-0-1', 'n_cells_by_counts-1-0-0-0-0-1', 'mean_counts-1-0-0-0-0-1', 'pct_dropout_by_counts-1-0-0-0-0-1', 'total_counts-1-0-0-0-0-1', 'mt-1-0-0-0-1', 'rb-1-0-0-0-1', 'gene_name-1-0-0-0-1', 'mt-1-0-0-1', 'rb-1-0-0-1', 'mt-1-0-1', 'rb-1-0-1', 'mt-1-1', 'rb-1-1'
#     uns: 'cell_type_colors', 'dataset_id_colors', 'dendrogram_cell_type', 'leiden', 'leiden_1_5_colors', 'leiden_man_colors', 'log1p', 'majority_voting_colors', 'rank_genes_groups', 'relabeled_cells_colors', 'scvi_neighbors', 'umap', '_scvi_uuid', '_scvi_manager_uuid', 'neighbors'
#     obsm: 'X_pca', 'X_scVI', 'X_umap', 'X_scANVI'
#     layers: 'counts'
#     obsp: 'scvi_neighbors_connectivities', 'scvi_neighbors_distances', 'distances', 'connectivities'

# %%
dir_path_scan = "/nfs/team205/bh14/Datasets/Remapped/raw_adata/SCVI_Results/All_Tissue_or_Nonimmune/Subset/scvi_model_Myeloid_From_Tissue_Subset_5_model_scanvi_2/"
vae_ref_scan.save(dir_path_scan, overwrite=True)

# %%
scvi.model.SCVI.prepare_query_anndata(adata=adata_query, reference_model=dir_path_scan)
# Out:
# INFO     File /nfs/team205/bh14/Datasets/Remapped/raw_adata/SCVI_Results/All_Tissue_or_Nonimm
#          une/Subset/scvi_model_Myeloid_From_Tissue_Subset_5_model_scanvi_2/model.pt already
#          downloaded
# INFO     Found 75.85% reference vars in query data.

# %%
vae_q = scvi.model.SCANVI.load_query_data(
    adata_query,
    dir_path_scan,
)
# Out:
# INFO     File /nfs/team205/bh14/Datasets/Remapped/raw_adata/SCVI_Results/All_Tissue_or_Nonimm
#          une/Subset/scvi_model_Myeloid_From_Tissue_Subset_5_model_scanvi_2/model.pt already
#          downloaded

# %%
vae_q._unlabeled_indices = np.arange(adata_query.n_obs)
vae_q._labeled_indices = []

# %%
vae_q.train(
    max_epochs=200,
    plan_kwargs=dict(weight_decay=0.0),
    check_val_every_n_epoch=10,
)
# Out:
# INFO     Training for 200 epochs.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 200/200: 100%|██████████| 200/200 [31:00<00:00,  9.30s/it, loss=809, v_num=1]

# %%
adata_query.obsm["X_scANVI"] = vae_q.get_latent_representation()

# %% [markdown]
# ## Analyze reference and query

# %%
adata_full = adata_query.concatenate(adata_ref)

# %%
adata_full.obs.batch.cat.rename_categories(["Query", "Reference"], inplace=True)

# %%
full_predictions = vae_q.predict(adata_full)

adata_full.obs["Cell_type_scANVI"] = full_predictions
# Out:
# INFO     Input AnnData not setup with scvi-tools. attempting to transfer AnnData setup

# %%
sc.pp.neighbors(adata_full, use_rep="X_scANVI", n_pcs=30, n_neighbors=50, key_added='scanvi_neighbors')
# Out:
# computing neighbors
#     finished: added to `.uns['scanvi_neighbors']`
#     `.obsp['scanvi_neighbors_distances']`, distances for each pair of neighbors
#     `.obsp['scanvi_neighbors_connectivities']`, weighted adjacency matrix (0:00:46)

# %%
sc.tl.leiden(adata_full, neighbors_key='scanvi_neighbors')
# Out:
# running Leiden clustering
#     finished: found 21 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:01:14)

# %%
sc.tl.umap(adata_full, min_dist=0.7, neighbors_key='scanvi_neighbors', spread=2)
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:02:18)

# %%
sc.pl.umap(
    adata_full,
    color=["leiden", "Cell_type_scANVI", "dataset_id"],
    frameon=False,
    ncols=1,
    size=12,
    legend_loc="on data"
)
# Out:
# ... storing 'tissue' as categorical
# ... storing 'disease' as categorical
# ... storing 'donor_id' as categorical
# ... storing 'dataset_id' as categorical
# ... storing 'cell_source' as categorical
# ... storing 'sex' as categorical
# ... storing 'development_stage' as categorical
# ... storing 'orig.ident' as categorical
# ... storing 'Site' as categorical
# ... storing 'leiden_1_5' as categorical
# ... storing 'predicted_labels' as categorical
# ... storing 'majority_voting' as categorical
# ... storing 'cell_type' as categorical
# ... storing 'barcodes' as categorical
# ... storing 'disease_status' as categorical
# ... storing 'developmental_stage' as categorical
# ... storing 'tissue_harmo' as categorical
# ... storing 'leiden_man' as categorical
# ... storing 'leiden_R' as categorical
# ... storing 'relabeled_cells' as categorical
# ... storing 'Cell_type_scANVI' as categorical

# %%
sc.pl.dotplot(adata_full, ['CLEC9A', 'DNASE1L3', 'IDO1', 'XCR1', 'FCER1A', 'S100A9',
               'CLEC10A', 'CD1C', 'PKIB', 'FSCN1', 'CD14', 'FCGR3B'],
              groupby='Cell_type_scANVI', standard_scale='var', cmap='OrRd', swap_axes=False)

# %%
#adata_full.obs['Cell_type_scANVI_2'] 
sc.pl.umap(
    adata_full,
    color=["Cell_type_scANVI"],
    frameon=False,
    ncols=1,
    size=12
)

# %%
adata_full.obs.age = adata_full.obs.age.astype("category")

# %% [markdown]
# #### Label transfert

# %%
def save_x_scvi(adata,data_dir, file_name, vae):
    """
    data_dir path to save scvi embedding
    file_name name for example Immune_compartment_PBMC
    """
    x_scanvi = vae.get_latent_representation(adata)
    outname = "{fname}.scVI_out.npy".format(fname=file_name)
    modelname = "{fname}_scvi_model".format(fname=file_name)
    np.save(data_dir + outname, x_scanvi)
    vae.save(data_dir + modelname, overwrite=True)
    pd.DataFrame(adata.obs).to_csv(data_dir+outname+".obs.csv")
    np.save(data_dir + file_name+".UMAP.npy", adata.obsm["X_umap"])
    #adata.obs[["leiden"]].to_csv(dir_save + "All_from_Tissue_QC_filtered.clustering_5.csv")

# %%
save_x_scvi(adata=adata_full, data_dir=dir_save+"scANVI_Myeloid_cells_out_2/", file_name="Myeloid_cell_from_Tissue_scANVI_2", vae=vae_q)

# %%
dir_save+"scANVI_Myeloid_cells_out_2/"
# Out:
# '/nfs/team205/bh14/Datasets/Remapped/raw_adata/SCVI_Results/All_Tissue_or_Nonimmune/Subset/scANVI_Myeloid_cells_out_2/'

# %%
adata_full.obs.over_clustering = adata_full.obs.over_clustering.astype("str")

# %%
adata_full
# Out:
# AnnData object with n_obs × n_vars = 86945 × 2000
#     obs: 'tissue', 'disease', 'donor_id', 'dataset_id', 'cell_source', 'doublet_scores', 'predicted_doublets', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rb', 'pct_counts_rb', 'QC', 'sex', 'development_stage', 'batch', 'orig.ident', 'Site', 'n_genes', 'leiden_1_5', 'predicted_labels', 'over_clustering', 'majority_voting', 'conf_score', '_scvi_batch', 'cell_type', '_scvi_labels', 'barcodes', 'disease_status', 'age', 'developmental_stage', 'barcode', 'sample_id', 'Enrichment', 'Location', 'full_clustering', 'log1p_total_counts', 'author_annotation', 'tissue_harmo', 'leiden', 'leiden_man', 'score', 'leiden_R', 'relabeled_cells', 'Cell_type_scANVI'
#     var: 'mt-0', 'rb-0', 'n_cells_by_counts-0-0-0-0', 'mean_counts-0-0-0-0', 'pct_dropout_by_counts-0-0-0-0', 'total_counts-0-0-0-0', 'n_cells_by_counts-1-0-0-0', 'mean_counts-1-0-0-0', 'pct_dropout_by_counts-1-0-0-0', 'total_counts-1-0-0-0', 'n_cells_by_counts-1-0-0', 'mean_counts-1-0-0', 'pct_dropout_by_counts-1-0-0', 'total_counts-1-0-0', 'n_cells_by_counts-1-0', 'mean_counts-1-0', 'pct_dropout_by_counts-1-0', 'total_counts-1-0', 'n_cells_by_counts-1-0-0-1', 'mean_counts-1-0-0-1', 'pct_dropout_by_counts-1-0-0-1', 'total_counts-1-0-0-1', 'n_cells_by_counts-1-0-1', 'mean_counts-1-0-1', 'pct_dropout_by_counts-1-0-1', 'total_counts-1-0-1', 'mt-0-1', 'rb-0-1', 'n_cells_by_counts-0-0-0-0-0-1', 'mean_counts-0-0-0-0-0-1', 'pct_dropout_by_counts-0-0-0-0-0-1', 'total_counts-0-0-0-0-0-1', 'n_cells_by_counts-1-0-0-0-0-1', 'mean_counts-1-0-0-0-0-1', 'pct_dropout_by_counts-1-0-0-0-0-1', 'total_counts-1-0-0-0-0-1', 'gene_ids-1-0-0-0-0-1', 'feature_types-1-0-0-0-0-1', 'n_cells_by_counts-1-0-0-0-1', 'mean_counts-1-0-0-0-1', 'pct_dropout_by_counts-1-0-0-0-1', 'total_counts-1-0-0-0-1', 'n_cells_by_counts-1-0-0-0-1-1', 'mean_counts-1-0-0-0-1-1', 'pct_dropout_by_counts-1-0-0-0-1-1', 'total_counts-1-0-0-0-1-1', 'n_cells_by_counts-1-0-0-1-1', 'mean_counts-1-0-0-1-1', 'pct_dropout_by_counts-1-0-0-1-1', 'total_counts-1-0-0-1-1', 'n_cells_by_counts-1-0-1-1', 'mean_counts-1-0-1-1', 'pct_dropout_by_counts-1-0-1-1', 'total_counts-1-0-1-1', 'n_cells_by_counts-1-1-1', 'mean_counts-1-1-1', 'pct_dropout_by_counts-1-1-1', 'total_counts-1-1-1', 'mt-0-0-0-0-1-1', 'rb-0-0-0-0-1-1', 'n_cells_by_counts-0-0-0-0-0-0-0-1-1', 'mean_counts-0-0-0-0-0-0-0-1-1', 'pct_dropout_by_counts-0-0-0-0-0-0-0-1-1', 'total_counts-0-0-0-0-0-0-0-1-1', 'n_cells_by_counts-1-0-0-0-0-0-0-1-1', 'mean_counts-1-0-0-0-0-0-0-1-1', 'pct_dropout_by_counts-1-0-0-0-0-0-0-1-1', 'total_counts-1-0-0-0-0-0-0-1-1', 'ensembl-1-0-0-0-0-0-0-1-1', 'gene_symbol-1-0-0-0-0-0-0-1-1', 'n_cells_by_counts-1-0-0-0-0-0-1-1', 'mean_counts-1-0-0-0-0-0-1-1', 'pct_dropout_by_counts-1-0-0-0-0-0-1-1', 'total_counts-1-0-0-0-0-0-1-1', 'n_cells_by_counts-1-0-0-0-0-1-1', 'mean_counts-1-0-0-0-0-1-1', 'pct_dropout_by_counts-1-0-0-0-0-1-1', 'total_counts-1-0-0-0-0-1-1', 'mt-1-0-0-0-1-1', 'rb-1-0-0-0-1-1', 'gene_name-1-0-0-0-1-1', 'mt-1-0-0-1-1', 'rb-1-0-0-1-1', 'mt-1-0-1-1', 'rb-1-0-1-1', 'mt-1-1-1', 'rb-1-1-1'
#     uns: '_scvi_uuid', '_scvi_manager_uuid', 'scanvi_neighbors', 'leiden', 'umap', 'leiden_colors', 'Cell_type_scANVI_colors', 'dataset_id_colors'
#     obsm: 'X_pca', 'X_scVI', 'X_umap', 'X_scANVI'
#     layers: 'counts'
#     obsp: 'scanvi_neighbors_distances', 'scanvi_neighbors_connectivities'

# %%
##### Get the obs of the full dataset with all common genes

# %%
pd.DataFrame(adata_full.obs).to_csv(dir_save+"scANVI_Myeloid_cells_out_2/Myeloid_cell_from_Tissue_scANVI.obs_2.csv")

# %%
adata_full.obs[["leiden"]].to_csv(dir_save+"scANVI_Myeloid_cells_out_2/Myeloid_cell_from_PBMC_scANVI.clustering_2.csv")

# %%
pd.DataFrame(adata_full.obs)
# Out:
#                                                       tissue  \
# AACTCCCTCGTCACGG-1_0_0_0-0                           Thyroid
# AACTCTTAGGAGCGAG-1_0_0_0-0                           Thyroid
# AAGGTTCCACATTTCT-1_0_0_0-0                           Thyroid
# ACCGTAAGTCTCTTTA-1_0_0_0-0                           Thyroid
# ACGATGTCACGGTAAG-1_0_0_0-0                           Thyroid
# ...                                                      ...
# TGCCCATAGGCCATAG-1-1-1-1-1-1-1_1_0_0-1-1  Retrosigmoid Colon
# TGCGTGGCACAAGCCC-1-1-1-1-1-1-1_1_0_0-1-1  Retrosigmoid Colon
# TTAGTTCAGAATAGGG-1-1-1-1-1-1-1_1_0_0-1-1  Retrosigmoid Colon
# TTGTAGGGTGCAGTAG-1-1-1-1-1-1-1_1_0_0-1-1  Retrosigmoid Colon
# TTTGTCATCGCCGTGA-1-1-1-1-1-1-1_1_0_0-1-1  Retrosigmoid Colon
#
#                                                           disease  \
# AACTCCCTCGTCACGG-1_0_0_0-0                Hashimoto’s thyroiditis
# AACTCTTAGGAGCGAG-1_0_0_0-0                Hashimoto’s thyroiditis
# AAGGTTCCACATTTCT-1_0_0_0-0                Hashimoto’s thyroiditis
# ACCGTAAGTCTCTTTA-1_0_0_0-0                Hashimoto’s thyroiditis
# ACGATGTCACGGTAAG-1_0_0_0-0                Hashimoto’s thyroiditis
# ...                                                           ...
# TGCCCATAGGCCATAG-1-1-1-1-1-1-1_1_0_0-1-1   CD + Spondyloarthritis
# TGCGTGGCACAAGCCC-1-1-1-1-1-1-1_1_0_0-1-1   CD + Spondyloarthritis
# TTAGTTCAGAATAGGG-1-1-1-1-1-1-1_1_0_0-1-1   CD + Spondyloarthritis
# TTGTAGGGTGCAGTAG-1-1-1-1-1-1-1_1_0_0-1-1   CD + Spondyloarthritis
# TTTGTCATCGCCGTGA-1-1-1-1-1-1-1_1_0_0-1-1   CD + Spondyloarthritis
#
#                                                             donor_id  \
# AACTCCCTCGTCACGG-1_0_0_0-0                               HT12Thyroid
# AACTCTTAGGAGCGAG-1_0_0_0-0                               HT12Thyroid
# AAGGTTCCACATTTCT-1_0_0_0-0                               HT12Thyroid
# ACCGTAAGTCTCTTTA-1_0_0_0-0                               HT12Thyroid
# ACGATGTCACGGTAAG-1_0_0_0-0                               HT12Thyroid
# ...                                                              ...
# TGCCCATAGGCCATAG-1-1-1-1-1-1-1_1_0_0-1-1  Patient_2_Colon_GSM4976992
# TGCGTGGCACAAGCCC-1-1-1-1-1-1-1_1_0_0-1-1  Patient_2_Colon_GSM4976992
# TTAGTTCAGAATAGGG-1-1-1-1-1-1-1_1_0_0-1-1  Patient_2_Colon_GSM4976992
# TTGTAGGGTGCAGTAG-1-1-1-1-1-1-1_1_0_0-1-1  Patient_2_Colon_GSM4976992
# TTTGTCATCGCCGTGA-1-1-1-1-1-1-1_1_0_0-1-1  Patient_2_Colon_GSM4976992
#
#                                                        dataset_id cell_source  \
# AACTCCCTCGTCACGG-1_0_0_0-0                    Qian_Yue_Zhang_2022     Thyroid
# AACTCTTAGGAGCGAG-1_0_0_0-0                    Qian_Yue_Zhang_2022     Thyroid
# AAGGTTCCACATTTCT-1_0_0_0-0                    Qian_Yue_Zhang_2022     Thyroid
# ACCGTAAGTCTCTTTA-1_0_0_0-0                    Qian_Yue_Zhang_2022     Thyroid
# ACGATGTCACGGTAAG-1_0_0_0-0                    Qian_Yue_Zhang_2022     Thyroid
# ...                                                           ...         ...
# TGCCCATAGGCCATAG-1-1-1-1-1-1-1_1_0_0-1-1  GSE163314_Lefferts_2021       Colon
# TGCGTGGCACAAGCCC-1-1-1-1-1-1-1_1_0_0-1-1  GSE163314_Lefferts_2021       Colon
# TTAGTTCAGAATAGGG-1-1-1-1-1-1-1_1_0_0-1-1  GSE163314_Lefferts_2021       Colon
# TTGTAGGGTGCAGTAG-1-1-1-1-1-1-1_1_0_0-1-1  GSE163314_Lefferts_2021       Colon
# TTTGTCATCGCCGTGA-1-1-1-1-1-1-1_1_0_0-1-1  GSE163314_Lefferts_2021       Colon
#
#                                           doublet_scores  predicted_doublets  \
# AACTCCCTCGTCACGG-1_0_0_0-0                      0.041894               False
# AACTCTTAGGAGCGAG-1_0_0_0-0                      0.149655               False
# AAGGTTCCACATTTCT-1_0_0_0-0                      0.117052               False
# ACCGTAAGTCTCTTTA-1_0_0_0-0                      0.057222               False
# ACGATGTCACGGTAAG-1_0_0_0-0                      0.092736               False
# ...                                                  ...                 ...
# TGCCCATAGGCCATAG-1-1-1-1-1-1-1_1_0_0-1-1        0.041203               False
# TGCGTGGCACAAGCCC-1-1-1-1-1-1-1_1_0_0-1-1        0.105647               False
# TTAGTTCAGAATAGGG-1-1-1-1-1-1-1_1_0_0-1-1        0.123907               False
# TTGTAGGGTGCAGTAG-1-1-1-1-1-1-1_1_0_0-1-1        0.127396               False
# TTTGTCATCGCCGTGA-1-1-1-1-1-1-1_1_0_0-1-1        0.221367               False
#
#                                           n_genes_by_counts  total_counts  \
# AACTCCCTCGTCACGG-1_0_0_0-0                              738        2282.0
# AACTCTTAGGAGCGAG-1_0_0_0-0                             2545       11133.0
# AAGGTTCCACATTTCT-1_0_0_0-0                             2100       14322.0
# ACCGTAAGTCTCTTTA-1_0_0_0-0                             1281        3949.0
# ACGATGTCACGGTAAG-1_0_0_0-0                             1904        9493.0
# ...                                                     ...           ...
# TGCCCATAGGCCATAG-1-1-1-1-1-1-1_1_0_0-1-1               2234       10640.0
# TGCGTGGCACAAGCCC-1-1-1-1-1-1-1_1_0_0-1-1               2483       10273.0
# TTAGTTCAGAATAGGG-1-1-1-1-1-1-1_1_0_0-1-1               2623       10297.0
# TTGTAGGGTGCAGTAG-1-1-1-1-1-1-1_1_0_0-1-1               2773       11568.0
# TTTGTCATCGCCGTGA-1-1-1-1-1-1-1_1_0_0-1-1                993        2732.0
#
#                                           total_counts_mt  ...  \
# AACTCCCTCGTCACGG-1_0_0_0-0                           84.0  ...
# AACTCTTAGGAGCGAG-1_0_0_0-0                          295.0  ...
# AAGGTTCCACATTTCT-1_0_0_0-0                          246.0  ...
# ACCGTAAGTCTCTTTA-1_0_0_0-0                          409.0  ...
# ACGATGTCACGGTAAG-1_0_0_0-0                          312.0  ...
# ...                                                   ...  ...
# TGCCCATAGGCCATAG-1-1-1-1-1-1-1_1_0_0-1-1            323.0  ...
# TGCGTGGCACAAGCCC-1-1-1-1-1-1-1_1_0_0-1-1            313.0  ...
# TTAGTTCAGAATAGGG-1-1-1-1-1-1-1_1_0_0-1-1            266.0  ...
# TTGTAGGGTGCAGTAG-1-1-1-1-1-1-1_1_0_0-1-1            255.0  ...
# TTTGTCATCGCCGTGA-1-1-1-1-1-1-1_1_0_0-1-1             88.0  ...
#
#                                           full_clustering  log1p_total_counts  \
# AACTCCCTCGTCACGG-1_0_0_0-0                            NaN                 NaN
# AACTCTTAGGAGCGAG-1_0_0_0-0                            NaN                 NaN
# AAGGTTCCACATTTCT-1_0_0_0-0                            NaN                 NaN
# ACCGTAAGTCTCTTTA-1_0_0_0-0                            NaN                 NaN
# ACGATGTCACGGTAAG-1_0_0_0-0                            NaN                 NaN
# ...                                                   ...                 ...
# TGCCCATAGGCCATAG-1-1-1-1-1-1-1_1_0_0-1-1              NaN                 NaN
# TGCGTGGCACAAGCCC-1-1-1-1-1-1-1_1_0_0-1-1              NaN                 NaN
# TTAGTTCAGAATAGGG-1-1-1-1-1-1-1_1_0_0-1-1              NaN                 NaN
# TTGTAGGGTGCAGTAG-1-1-1-1-1-1-1_1_0_0-1-1              NaN                 NaN
# TTTGTCATCGCCGTGA-1-1-1-1-1-1-1_1_0_0-1-1              NaN                 NaN
#
#                                           author_annotation tissue_harmo  \
# AACTCCCTCGTCACGG-1_0_0_0-0                              NaN          NaN
# AACTCTTAGGAGCGAG-1_0_0_0-0                              NaN          NaN
# AAGGTTCCACATTTCT-1_0_0_0-0                              NaN          NaN
# ACCGTAAGTCTCTTTA-1_0_0_0-0                              NaN          NaN
# ACGATGTCACGGTAAG-1_0_0_0-0                              NaN          NaN
# ...                                                     ...          ...
# TGCCCATAGGCCATAG-1-1-1-1-1-1-1_1_0_0-1-1                NaN        Colon
# TGCGTGGCACAAGCCC-1-1-1-1-1-1-1_1_0_0-1-1                NaN        Colon
# TTAGTTCAGAATAGGG-1-1-1-1-1-1-1_1_0_0-1-1                NaN        Colon
# TTGTAGGGTGCAGTAG-1-1-1-1-1-1-1_1_0_0-1-1                NaN        Colon
# TTTGTCATCGCCGTGA-1-1-1-1-1-1-1_1_0_0-1-1                NaN        Colon
#
#                                          leiden leiden_man     score leiden_R  \
# AACTCCCTCGTCACGG-1_0_0_0-0                    3        NaN       NaN      NaN
# AACTCTTAGGAGCGAG-1_0_0_0-0                   16        NaN       NaN      NaN
# AAGGTTCCACATTTCT-1_0_0_0-0                    3        NaN       NaN      NaN
# ACCGTAAGTCTCTTTA-1_0_0_0-0                    3        NaN       NaN      NaN
# ACGATGTCACGGTAAG-1_0_0_0-0                    3        NaN       NaN      NaN
# ...                                         ...        ...       ...      ...
# TGCCCATAGGCCATAG-1-1-1-1-1-1-1_1_0_0-1-1      3          1  0.311463        1
# TGCGTGGCACAAGCCC-1-1-1-1-1-1-1_1_0_0-1-1      8          1  0.943661        1
# TTAGTTCAGAATAGGG-1-1-1-1-1-1-1_1_0_0-1-1     11        7,0  0.278422      7,0
# TTGTAGGGTGCAGTAG-1-1-1-1-1-1-1_1_0_0-1-1      3          1  1.026061        1
# TTTGTCATCGCCGTGA-1-1-1-1-1-1-1_1_0_0-1-1     11        7,0  0.300646      7,0
#
#                                          relabeled_cells  Cell_type_scANVI
# AACTCCCTCGTCACGG-1_0_0_0-0                           NaN               pDC
# AACTCTTAGGAGCGAG-1_0_0_0-0                           NaN               pDC
# AAGGTTCCACATTTCT-1_0_0_0-0                           NaN            Mig DC
# ACCGTAAGTCTCTTTA-1_0_0_0-0                           NaN             Mac_2
# ACGATGTCACGGTAAG-1_0_0_0-0                           NaN               DC2
# ...                                                  ...               ...
# TGCCCATAGGCCATAG-1-1-1-1-1-1-1_1_0_0-1-1             DC2               DC2
# TGCGTGGCACAAGCCC-1-1-1-1-1-1-1_1_0_0-1-1             DC2   Mac S100A8 prod
# TTAGTTCAGAATAGGG-1-1-1-1-1-1-1_1_0_0-1-1             7,0             Mac_1
# TTGTAGGGTGCAGTAG-1-1-1-1-1-1-1_1_0_0-1-1             DC2               DC2
# TTTGTCATCGCCGTGA-1-1-1-1-1-1-1_1_0_0-1-1             7,0             Mac_1
#
# [86945 rows x 46 columns]

# %%
for dis in adata_full.obs.dataset_id.unique():
    print(dis)
    sc.pl.umap(
        adata_full,
        groups=dis,
        color=["dataset_id"],
        frameon=False,
        size=20,
        ncols=2,
        legend_loc="on data"
    )
# Out:
# ... storing 'over_clustering' as categorical
# Qian_Yue_Zhang_2022
# Martin_JIA_2019
# AMP_phase1_RA
# Kong_et_al_2023
# GSE121380_Huang_2019
# E-MTAB-8322_Stefeno_2020
# GSE161500_Abji_2020
# E-MTAB-9492_Penkava_2020
# GSE134809_Martin_et_al_2019
# Elmentaite_2020
# GSE163314_Lefferts_2021
